# %%
import pandas as pd

# %%
anomalydae=pd.read_csv('./anomalydae.csv')

# %%
anomalydae[anomalydae['dataset']=='Cora'].sort_values('auc',ascending=False)
# Out:
#      dataset  seed  feat_size  num_nodes  embed_dim  out_dim  dropout  \
# 1326    Cora    42       1433       2708        256      128      0.2
# 1176    Cora    42       1433       2708        256      128      0.2
# 722     Cora    42       1433       2708        256      128      0.2
# 1472    Cora    42       1433       2708        256      128      0.2
# 1622    Cora    42       1433       2708        256      128      0.2
# ...      ...   ...        ...        ...        ...      ...      ...
# 441     Cora    42       1433       2708        256      128      0.2
# 586     Cora    42       1433       2708        256      128      0.2
# 136     Cora    42       1433       2708        256      128      0.2
# 286     Cora    42       1433       2708        256      128      0.2
# 436     Cora    42       1433       2708        256      128      0.2
#
#            lr                logdir  num_epoch  alpha  eta  theta  device  \
# ...
